# %% [markdown]
# # Setup

# %%
# !python -m pip install -U pip
# !python -m pip install pillow-heif
# !pip install rembg
# !pip install PIL

# %%
import os
import glob
from PIL import Image
from pillow_heif import register_heif_opener
from rembg import remove
import glob
import shutil
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models, Input, callbacks

# %% [markdown]
# # Preprocessing

# %% [markdown]
# <ul>
#     <li>Resize the images to 512x512</li>
#     <li>Remove background noise</li>
#     <li>Convert from RBGA to RGB</li>
#     <li>Save it with proper format -JPEG- in another file</li>
# </ul>

# %%
register_heif_opener() # Enable support for HEIF images, including HEIC, AVIF, and other formats

# Define target format (e.g., JPEG), size (e.g., 224x224), and quality (0-100)
target_format = "JPEG"
target_size = (512, 512)
quality = 100

# Define path to your image directory
for classname in ['rock', 'paper', 'scissor']:
    src_dir = f"..\\..\\raw_data\\{classname}"
    dst_dir = f"..\\datasets\\procssed_data\\{classname}"

    os.makedirs(dst_dir, exist_ok=True) # Create destination directory if it doesn't exist

    # Find all images using glob
    for filepath in glob.glob(f"{src_dir}\\*"):
        try:
            # Open image with Pillow
            img = Image.open(filepath)

            # Resize image
            img = img.resize(target_size)

            # Removing the background from the given Image
            img = remove(img)

            # Convering it to the proper format RGB instead of RBGA
            img = img.convert('L') # 'L' for black and white :)

            # Convert to target format and compress
            filename = filepath.split("\\")[-1].split(".")[0]
            img.save(f"{dst_dir}/{filename}.{target_format}", target_format, quality=quality)

            print(f"Converted to JPEG, resized and background removed {filepath}")
        except (OSError, IOError) as e:
            print('somthing went wrong in image proccecing',e)

# %% [markdown]
# ### Making sure JPEG is the only format in the output

# %%
formats = set()
filepaths = glob.glob('..\\datasets\\procssed_data\\*\\*')

for f in filepaths:
    formats.add(f.split('.')[-1].lower())

print(f'{formats} Must be only JPEG/JPG')
# Out:
# {'jpeg'} Must be only JPEG/JPG

# %% [markdown]
# ### Count number of `input` vs `output`

# %%
filepaths_not_processed = glob.glob('..\\..\\raw_data\\*\\*')
filepaths_processed = glob.glob('..\\datasets\\procssed_data\\*\\*')
print(f'{len(filepaths_not_processed)} is number of images in raw_data')
print(f'{len(filepaths_processed)} is number of images in processed_data')
# Out:
# 843 is number of images in raw_data
# 841 is number of images in processed_data

# %% [markdown]
# # Split dataset into `train` and `test` folders

# %% [markdown]
# ## Loading image names with their labels as keys
#
#  `{ paper:['img'...], rock:[...], ... }`

# %%
images = {}

for filename in glob.glob('..\\datasets\\procssed_data\\*\\*'):
    split = filename.split('\\')
    classname = split[-2]
    if classname not in images:
        images[classname] = []
    images[classname].append(split[-1])

# %%
images

# %%
# For demestration only
x = [50, 70, 90]
random.shuffle(x)
x
# Out:
# [70, 50, 90]

# %% [markdown]
# ## Splite by copying them to a new folder

# %%
for classname in images.keys():
    # shuffl the images
    random.shuffle(images[classname])

for classname in images.keys():
    os.makedirs(f'..\\datasets\\data_split\\train\\{classname}', exist_ok=True)
    os.makedirs(f'..\\datasets\\data_split\\valid\\{classname}', exist_ok=True)
    os.makedirs(f'..\\datasets\\data_split\\test\\{classname}', exist_ok=True)

    # 70% for training , 20% validation and 10% testing
    for i, image in enumerate(images[classname]):
        if i < len(images[classname]) * 0.7:
            shutil.copyfile(f'..\\datasets\\procssed_data\\{classname}/{image}', f'..\\datasets\\data_split\\train\\{classname}/{image}')
        elif i < len(images[classname]) * 0.9:
            shutil.copyfile(f'..\\datasets\\procssed_data\\{classname}/{image}', f'..\\datasets\\data_split\\valid\\{classname}/{image}')
        else:
            shutil.copyfile(f'..\\datasets\\procssed_data\\{classname}/{image}', f'..\\datasets\\data_split\\test\\{classname}/{image}')

# %% [markdown]
# ## Load `train`, `test` and `val` from the new folder data_split

# %%
IMG_SIZE = 512
BATCH_SIZE = 32

splited_data_dir = "/content/data_split"

# Load training dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
    splited_data_dir + '/train',
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
)

# Load validation dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
    splited_data_dir + '/valid',
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
)

# Load test dataset
test_ds = tf.keras.utils.image_dataset_from_directory(
    splited_data_dir + '/test',
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
)


print(train_ds.class_names)
# Out:
# Found 590 files belonging to 3 classes.
# Found 169 files belonging to 3 classes.
# Found 82 files belonging to 3 classes.
# ['paper', 'rock', 'scissor']

# %% [markdown]
# ### A sample

# %%
def display_image(image):
    plt.axis('off')
    plt.imshow(image)

for images, label in val_ds.take(1):
    display_image(images[0])
    break
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Neurons network architectures

# %%
input_shape = (512, 512, 1)

model = models.Sequential([
    layers.Input(),
    layers.BatchNormalization(),

    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.GlobalAveragePooling2D(),

    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(64, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(32, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(3, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ batch_normalization_5           │ (None, 512, 512, 1)    │             4 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 510, 510, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 510, 510, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 255, 255, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 253, 253, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 253, 253, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 126, 126, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 124, 124, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 124, 124, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 60,999 (238.28 KB)
#  Trainable params: 60,549 (236.52 KB)
#  Non-trainable params: 450 (1.76 KB)

# %%
history = model.fit(train_ds, validation_data=val_ds,epochs=10)
# Out:
# Epoch 1/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 86s 5s/step - accuracy: 0.7544 - loss: 0.5932 - val_accuracy: 0.3432 - val_loss: 2.6063
# Epoch 2/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 155s 8s/step - accuracy: 0.7384 - loss: 0.6256 - val_accuracy: 0.3432 - val_loss: 2.9205
# Epoch 3/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 149s 8s/step - accuracy: 0.7951 - loss: 0.5503 - val_accuracy: 0.3432 - val_loss: 3.2390
# Epoch 4/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 158s 8s/step - accuracy: 0.8045 - loss: 0.5476 - val_accuracy: 0.3432 - val_loss: 2.8540
# Epoch 5/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 166s 8s/step - accuracy: 0.8150 - loss: 0.5023 - val_accuracy: 0.3432 - val_loss: 3.5628
# Epoch 6/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 152s 8s/step - accuracy: 0.8268 - loss: 0.4433 - val_accuracy: 0.3432 - val_loss: 3.4228
# Epoch 7/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 183s 10s/step - accuracy: 0.8223 - loss: 0.5060 - val_accuracy: 0.3432 - val_loss: 3.2772
# Epoch 8/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 240s 12s/step - accuracy: 0.8426 - loss: 0.4197 - val_accuracy: 0.3432 - val_loss: 3.2250
# Epoch 9/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 173s 9s/step - accuracy: 0.8178 - loss: 0.4888 - val_accuracy: 0.3432 - val_loss: 3.5286
# Epoch 10/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 156s 8s/step - accuracy: 0.8126 - loss: 0.5576 - val_accuracy: 0.3432 - val_loss: 3.4417

# %%
model_2 = models.Sequential([
    layers.Input(shape=(512, 512, 1)),
    layers.BatchNormalization(),

    layers.Conv2D(32, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.Conv2D(64, (3, 3), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),

    layers.GlobalAveragePooling2D(),

    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(96, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(60, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(40, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(29, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(3, activation='softmax')
])

model_2.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

# Define the ModelCheckpoint callback
model_checkpoint = callbacks.ModelCheckpoint('drive/MyDrive/best_model.keras', save_best_only=True)

# Early stopping callback
early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)

# %%
history = model_2.fit(train_ds, validation_data=val_ds, epochs=100, callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 19/19 [==============================] - 13s 364ms/step - loss: 1.4087 - accuracy: 0.3441 - val_loss: 1.0979 - val_accuracy: 0.3550
# Epoch 2/100
# 19/19 [==============================] - 7s 382ms/step - loss: 1.2867 - accuracy: 0.3949 - val_loss: 1.0986 - val_accuracy: 0.3432
# Epoch 3/100
# 19/19 [==============================] - 7s 344ms/step - loss: 1.2367 - accuracy: 0.4017 - val_loss: 1.0983 - val_accuracy: 0.3432
# Epoch 4/100
# 19/19 [==============================] - 7s 350ms/step - loss: 1.1218 - accuracy: 0.4763 - val_loss: 1.0995 - val_accuracy: 0.3432
# Epoch 5/100
# 19/19 [==============================] - 7s 346ms/step - loss: 1.1581 - accuracy: 0.4271 - val_loss: 1.1013 - val_accuracy: 0.3432
# Epoch 6/100
# 19/19 [==============================] - 7s 342ms/step - loss: 1.0805 - accuracy: 0.4644 - val_loss: 1.1070 - val_accuracy: 0.3432
# Epoch 7/100
# 19/19 [==============================] - 7s 341ms/step - loss: 1.0714 - accuracy: 0.4847 - val_loss: 1.1107 - val_accuracy: 0.2840

# %% [markdown]
# ## Transform
#
# data is grayscale -> RGB

# %%
from tensorflow.keras.applications import EfficientNetV2M

efficientnetv2m = EfficientNetV2M(weights='imagenet', include_top=False, input_shape=(512, 512, 3))

efficientnetv2m.trainable = False

model_efficientnetv2m = models.Sequential([
    layers.Input(shape=(512, 512, 3)),
    efficientnetv2m,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(96, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(60, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(40, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(29, activation='relu'),
    layers.BatchNormalization(),
    layers.Dense(3, activation='softmax')
])

model_efficientnetv2m.compile(optimizer='adam',
                               loss='sparse_categorical_crossentropy',
                               metrics=['accuracy'])

model_checkpoint = callbacks.ModelCheckpoint('drive/MyDrive/best_model_efficientnetv2m.keras', save_best_only=True)

early_stopping = callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)

history_efficientnetv2m = model_efficientnetv2m.fit(train_ds,
                                                    validation_data=val_ds,
                                                    epochs=100,
                                                    callbacks=[early_stopping, model_checkpoint])
# Out:
# Epoch 1/100
# 19/19 [==============================] - 132s 3s/step - loss: 1.3227 - accuracy: 0.3983 - val_loss: 1.0350 - val_accuracy: 0.5207
# Epoch 2/100
# 19/19 [==============================] - 32s 2s/step - loss: 0.9569 - accuracy: 0.5678 - val_loss: 0.9942 - val_accuracy: 0.6331
# Epoch 3/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.8050 - accuracy: 0.6458 - val_loss: 0.9342 - val_accuracy: 0.6982
# Epoch 4/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.7794 - accuracy: 0.6593 - val_loss: 0.8271 - val_accuracy: 0.7633
# Epoch 5/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.6867 - accuracy: 0.7034 - val_loss: 0.7283 - val_accuracy: 0.7751
# Epoch 6/100
# 19/19 [==============================] - 32s 2s/step - loss: 0.6235 - accuracy: 0.7492 - val_loss: 0.6575 - val_accuracy: 0.7811
# Epoch 7/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.6606 - accuracy: 0.7424 - val_loss: 0.6550 - val_accuracy: 0.7337
# Epoch 8/100
# 19/19 [==============================] - 30s 2s/step - loss: 0.5591 - accuracy: 0.7746 - val_loss: 0.5655 - val_accuracy: 0.8047
# Epoch 9/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.5080 - accuracy: 0.7932 - val_loss: 0.4757 - val_accuracy: 0.8166
# Epoch 10/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.4901 - accuracy: 0.7966 - val_loss: 0.4310 - val_accuracy: 0.8402
# Epoch 11/100
# 19/19 [==============================] - 32s 2s/step - loss: 0.4787 - accuracy: 0.8068 - val_loss: 0.3708 - val_accuracy: 0.8343
# Epoch 12/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.4071 - accuracy: 0.8508 - val_loss: 0.2825 - val_accuracy: 0.9290
# Epoch 13/100
# 19/19 [==============================] - 30s 2s/step - loss: 0.4180 - accuracy: 0.8356 - val_loss: 0.2658 - val_accuracy: 0.9290
# Epoch 14/100
# 19/19 [==============================] - 30s 2s/step - loss: 0.3912 - accuracy: 0.8627 - val_loss: 0.2459 - val_accuracy: 0.9408
# Epoch 15/100
# 19/19 [==============================] - 27s 1s/step - loss: 0.3302 - accuracy: 0.8729 - val_loss: 0.2509 - val_accuracy: 0.9172
# Epoch 16/100
# 19/19 [==============================] - 32s 2s/step - loss: 0.3380 - accuracy: 0.8644 - val_loss: 0.2299 - val_accuracy: 0.9231
# Epoch 17/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.3302 - accuracy: 0.8814 - val_loss: 0.2207 - val_accuracy: 0.9231
# Epoch 18/100
# 19/19 [==============================] - 27s 1s/step - loss: 0.3497 - accuracy: 0.8644 - val_loss: 0.2460 - val_accuracy: 0.9172
# Epoch 19/100
# 19/19 [==============================] - 33s 2s/step - loss: 0.3012 - accuracy: 0.8847 - val_loss: 0.2614 - val_accuracy: 0.8994
# Epoch 20/100
# 19/19 [==============================] - 27s 1s/step - loss: 0.3402 - accuracy: 0.8729 - val_loss: 0.2272 - val_accuracy: 0.9231
# Epoch 21/100
# 19/19 [==============================] - 27s 1s/step - loss: 0.2793 - accuracy: 0.9051 - val_loss: 0.2401 - val_accuracy: 0.9231
# Epoch 22/100
# 19/19 [==============================] - 32s 2s/step - loss: 0.3007 - accuracy: 0.8746 - val_loss: 0.2415 - val_accuracy: 0.8994
# Epoch 23/100
# 19/19 [==============================] - 31s 2s/step - loss: 0.2687 - accuracy: 0.9068 - val_loss: 0.2120 - val_accuracy: 0.9290
# Epoch 24/100
# 19/19 [==============================] - 27s 1s/step - loss: 0.2789 - accuracy: 0.8983 - val_loss: 0.2197 - val_accuracy: 0.9231
# Epoch 25/100
# 19/19 [==============================] - 27s 1s/step - loss: 0.2925 - accuracy: 0.8831 - val_loss: 0.3125 - val_accuracy: 0.8817
# Epoch 26/100
# 19/19 [==============================] - 27s 1s/step - loss: 0.2567 - accuracy: 0.9085 - val_loss: 0.2793 - val_accuracy: 0.8994
# Epoch 27/100
# 19/19 [==============================] - 32s 2s/step - loss: 0.3130 - accuracy: 0.8695 - val_loss: 0.2279 - val_accuracy: 0.9053
# Epoch 28/100
# 19/19 [==============================] - 27s 1s/step - loss: 0.2192 - accuracy: 0.9203 - val_loss: 0.2279 - val_accuracy: 0.8994
# Epoch 29/100
# 19/19 [==============================] - 27s 1s/step - loss: 0.2464 - accuracy: 0.9102 - val_loss: 0.2309 - val_accuracy: 0.9112

# %% [markdown]
# # Evaluate & Loading the model in Google Colap (DONE after a disconnect)

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
# !unzip best_model_efficientnetv2m.zip
# Out:
# Archive:  best_model_efficientnetv2m.zip
#   inflating: best_model_efficientnetv2m.keras

# %%
import tensorflow as tf

# %%
# Load the saved model
loaded_model = tf.keras.models.load_model('/content/best_model_efficientnetv2m.keras')

# %%
IMG_SIZE = 512
BATCH_SIZE = 32

splited_data_dir = "/content"

# Load test dataset
test_ds = tf.keras.utils.image_dataset_from_directory(
    splited_data_dir + '/test',
    seed=123,
    image_size=(IMG_SIZE, IMG_SIZE),
    color_mode='rgb',
    batch_size=BATCH_SIZE,
)


print(test_ds.class_names)
# Out:
# Found 82 files belonging to 3 classes.
# ['paper', 'rock', 'scissor']

# %%
test_loss, test_accuracy = loaded_model.evaluate(test_ds)

# Print the test accuracy
print("Test Accuracy:", test_accuracy)
# Out:
# 3/3 [==============================] - 3s 765ms/step - loss: 0.1530 - accuracy: 0.9390
# Test Accuracy: 0.9390243887901306
